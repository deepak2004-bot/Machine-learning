# %%
import pandas as pd
import numpy as np
s1 = pd.Series(np.random.randint(1 , high=5 , size=100 , dtype='I' ))
s2 = pd.Series(np.random.randint(1 , high=4 , size=100 , dtype='I' ))
s3 = pd.Series(np.random.randint(10000 , high=30001 , size=100 , dtype='I'))

print(s1,s2,s3)
housemkt=pd.concat([s1 , s2 , s3],axis=1)
housemkt.head()
housemkt.rename(columns = {0: 'bedrs' , 2: 'price_sqr_meter'} , inplace=True)
housemkt.head()
#join concat the values
bigcolumn = pd.concat([s1 , s2 , s3 ] , axis=0 )

#it is still a series , so we need to transferm it to a DataFrame
bigcolumn = bigcolumn.to_frame()
print(type(bigcolumn))

bigcolumn
len(bigcolumn)
bigcolumn.reset_index(drop=True , inplace=True)
bigcolumn
# Out:
# 0     1
# 1     4
# 2     4
# 3     4
# 4     2
#      ..
# 95    3
# 96    1
# 97    2
# 98    3
# 99    3
# Length: 100, dtype: uint32 0     1
# 1     2
# 2     2
# 3     3
# 4     3
#      ..
# 95    1
# 96    1
# 97    3
# 98    2
# 99    3
# Length: 100, dtype: uint32 0     26715
# 1     16410
# 2     25756
# 3     28195
# 4     10447
#       ...
# 95    28562
# 96    12631
# 97    23230
# 98    29349
# 99    12130
# Length: 100, dtype: uint32
# <class 'pandas.core.frame.DataFrame'>
#          0
# 0        1
# 1        4
# 2        4
# 3        4
# 4        2
# ..     ...
# 295  28562
# 296  12631
# 297  23230
# 298  29349
# 299  12130
#
# [300 rows x 1 columns]

# %%
cars1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")
cars2 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")

# %%
print(cars1.head())
print(cars2.head())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %% [raw]
# cars1 = cars1.loc[:,"mpg":"car"]
# cars1.head()

# %%
print(cars1.shape)
print(cars2.shape)
# Out:
# (198, 14)
# (200, 9)

# %%
cars = pd.concat([cars1, cars2])
display(cars)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
# ...

# %%
nr_owners = np.random.randint(15000, 73001, size=398).astype(np.int32)
nr_owners
# Out:
# array([64400, 26231, 65844, 36029, 60594, 39186, 42990, 56244, 17705,
#        47314, 41156, 47314, 34178, 41662, 59636, 18460, 22716, 21829,
#        69783, 70674, 63935, 23308, 71911, 20382, 27812, 70735, 24269,
#        50370, 32482, 64264, 72659, 17180, 60071, 62014, 50484, 71508,
#        15399, 37924, 42517, 43894, 60227, 44783, 60051, 43966, 39720,
#        23895, 61778, 18751, 29671, 45024, 43839, 21842, 69330, 50992,
#        41834, 66444, 27119, 33416, 43498, 41553, 36888, 27659, 48249,
#        61915, 32146, 43977, 42360, 35683, 41539, 15937, 19192, 51028,
#        64515, 53649, 37114, 49374, 30171, 49165, 65619, 39517, 35960,
#        57802, 63986, 37922, 22507, 64739, 53000, 24702, 42425, 49944,
#        61727, 50122, 25896, 51127, 55134, 61754, 69037, 62297, 60534,
#        58566, 70422, 39357, 48579, 21490, 56805, 31604, 50659, 38625,
#        55566, 46730, 30328, 61851, 35894, 48894, 48482, 63317, 45457,
# ...

# %%
cars['owners'] = nr_owners
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin              car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 195       1  ford mustang gl         NaN          NaN          NaN
# 196       2        vw pickup         NaN          NaN          NaN
# 197       1    dodge rampage         NaN          NaN          NaN
# 198       1      ford ranger         NaN          NaN          NaN
# 199       1       chevy s-10         NaN          NaN          NaN
#
#      Unnamed: 12  Unnamed: 13  owners
# 195          NaN          NaN   53199
# ...
